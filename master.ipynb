# %%
import os
import csv
import json
import requests
from io import StringIO
from google.cloud import bigquery
from pdb import set_trace as b

# Only relevant when running locally
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/Users/louistronel/Desktop/Conseil_Quartier/Dans_ma_rue/Credentials/service-account-file.json"

def fetch_from_api():
    """
    Fetches the 'Dans ma rue' dataset from OpenData Paris API and filters it as needed.
    Returns a list of dictionaries (rows).
    """
    endpoint = "https://opendata.paris.fr/api/explore/v2.1/catalog/datasets/dans-ma-rue/exports/csv?"
    headers = {"User-Agent": "Mozilla/5.0"}

    try:
        response = requests.get(endpoint, headers=headers, timeout=5)
        response.raise_for_status()
        print("Success:", response.status_code)
    except requests.exceptions.Timeout:
        print("Request timed out!")
        return []
    except requests.exceptions.RequestException as e:
        print("Error:", e)
        return []

    # Read CSV into a list of dictionaries
    csv_data = StringIO(response.text)
    reader = csv.DictReader(csv_data, delimiter=';')
    reader.fieldnames = [col.lstrip('\ufeff') for col in reader.fieldnames] if reader.fieldnames else []
    data = [row for row in reader]

    # Convert specific fields
    for row in data:
        row["code_postal"] = str(row.get("code_postal", ""))
        row["anneedecl"] = str(row.get("anneedecl", ""))
        row["datedecl"] = row.get("datedecl", "").replace("/", "-")  # Format date

    print(f"Total records retrieved from API: {len(data)}")
    return data

def fetch_from_bigquery(project_id=None, dataset_id=None, table_id=None):
    """
    Fetches existing 'id_dmr' values from a BigQuery table.
    Returns a set of known 'id_dmr' values.
    """
    client = bigquery.Client()

    query = f"SELECT id_dmr FROM `{project_id}.{dataset_id}.{table_id}`"
    
    try:
        query_job = client.query(query)
        rows = list(query_job)
        known_ids = {str(row["id_dmr"]) for row in rows}
        print(f"Total records retrieved from bigquery table: {len(known_ids)}")
        return known_ids
    except Exception as e:
        print("Error fetching data from BigQuery:", e)
        return set()

def upload_to_bigquery(data, project_id=None, dataset_id=None, table_id=None, batch_size=10000):
    """
    Uploads a list of dictionaries (new records) to a BigQuery table in batches.
    """
    if not data:
        print("Skipping upload - No new records to insert.")
        return

    client = bigquery.Client()
    table_ref = client.dataset(dataset_id).table(table_id)

    # Upload data in batches
    for i in range(0, len(data), batch_size):
        batch = data[i:i + batch_size]
        try:
            errors = client.insert_rows_json(table_ref, batch)
            if errors:
                print(f"Errors during upload for batch starting at index {i}:", errors)
            else:
                print(f"Batch starting at index {i} successfully appended to {dataset_id}.{table_id}")
        except Exception as e:
            print(f"Error uploading batch starting at index {i} to BigQuery:", e)
            break


if __name__ == "__main__":

    # Get dataset from API
    data = fetch_from_api()

    # Get existing IDs from BigQuery
    known_ids = fetch_from_bigquery(
        project_id='conseil-quartier',
        dataset_id='dans_ma_rue', 
        table_id='feed_requetes_dmr'
    )

    # Filter out records already in BigQuery
    new_data = [row for row in data if row["id_dmr"] not in known_ids]
    print(f"{len(new_data)} records to append to table")

    # Upload new records to table
    upload_to_bigquery(
        new_data, 
        project_id='conseil-quartier', 
        dataset_id='dans_ma_rue', 
        table_id='feed_requetes_dmr'
    )
# Out:
# Success: 200
# Total records retrieved from API: 1085371
# Total records retrieved from bigquery table: 16984
# 1068484 records to append to table
# Batch starting at index 0 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 10000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 20000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 30000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 40000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 50000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 60000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 70000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 80000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 90000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 100000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 110000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 120000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 130000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 140000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 150000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 160000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 170000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 180000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 190000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 200000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 210000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 220000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 230000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 240000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 250000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 260000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 270000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 280000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 290000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 300000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 310000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 320000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 330000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 340000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 350000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 360000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 370000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 380000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 390000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 400000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 410000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 420000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 430000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 440000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 450000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 460000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 470000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 480000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 490000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 500000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 510000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 520000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 530000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 540000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 550000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 560000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 570000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 580000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 590000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 600000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 610000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 620000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 630000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 640000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 650000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 660000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 670000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 680000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 690000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 700000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 710000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 720000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 730000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 740000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 750000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 760000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 770000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 780000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 790000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 800000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 810000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 820000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 830000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 840000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 850000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 860000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 870000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 880000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 890000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 900000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 910000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 920000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 930000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 940000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 950000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 960000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 970000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 980000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 990000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 1000000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 1010000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 1020000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 1030000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 1040000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 1050000 successfully appended to dans_ma_rue.feed_requetes_dmr
# Batch starting at index 1060000 successfully appended to dans_ma_rue.feed_requetes_dmr
